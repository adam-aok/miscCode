# %%
import pandas as pd

# %%
df = pd.read_csv('adult.csv')

# %%
df
# Out:
#        39          State-gov   77516    Bachelors  13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 1      38            Private  215646      HS-grad   9             Divorced
# 2      53            Private  234721         11th   7   Married-civ-spouse
# 3      28            Private  338409    Bachelors  13   Married-civ-spouse
# 4      37            Private  284582      Masters  14   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32555  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad   9              Widowed
# 32558  22            Private  201490      HS-grad   9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2   77516           32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4   13              32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10  2174            32560 non-null  int64
#  11  0               32560 non-null  int64
#  12  40              32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
pd.set_option('display.max_columns',40)

# %%
schema_df = pd.read_csv('adult_attributes.txt',
                       sep=':')

# %%
schema_df
# Out:
#                age                                       continuous.
# 0        workclass   Private, Self-emp-not-inc, Self-emp-inc, Fede...
# 1           fnlwgt                                       continuous.
# 2        education   Bachelors, Some-college, 11th, HS-grad, Prof-...
# 3    education-num                                       continuous.
# 4   marital-status   Married-civ-spouse, Divorced, Never-married, ...
# 5       occupation   Tech-support, Craft-repair, Other-service, Sa...
# 6     relationship   Wife, Own-child, Husband, Not-in-family, Othe...
# 7             race   White, Asian-Pac-Islander, Amer-Indian-Eskimo...
# 8              sex                                     Female, Male.
# 9     capital-gain                                       continuous.
# 10    capital-loss                                       continuous.
# 11  hours-per-week                                       continuous.
# ...

# %%
schema_df['age'].values
# Out:
# array(['workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'], dtype=object)

# %%
headers = schema_df['age'].values

# %%
df.names = headers
# Out:
# <ipython-input-37-dd4ffe9e3ac3>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.names = headers

# %%
df = pd.read_csv('adult.csv',names=headers)

# %%
df['native-country'] = df['native-country'].str.replace('-',' ')

# %%
df
# Out:
#             workclass  fnlwgt    education  education-num  \
# 39          State-gov   77516    Bachelors             13
# 50   Self-emp-not-inc   83311    Bachelors             13
# 38            Private  215646      HS-grad              9
# 53            Private  234721         11th              7
# 28            Private  338409    Bachelors             13
# ..                ...     ...          ...            ...
# 27            Private  257302   Assoc-acdm             12
# 40            Private  154374      HS-grad              9
# 58            Private  151910      HS-grad              9
# 22            Private  201490      HS-grad              9
# 52       Self-emp-inc  287927      HS-grad              9
#
#          marital-status          occupation    relationship    race      sex  \
# 39        Never-married        Adm-clerical   Not-in-family   White     Male
# 50   Married-civ-spouse     Exec-managerial         Husband   White     Male
# ...

# %%
df.to_csv('transformed_data.csv')
